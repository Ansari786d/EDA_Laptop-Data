# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Data.csv')

# %%
df
# Out:
#     Rank Currency_Name  Market_Capital    Price  Circulating_Supply  \
# 0      1       Bitcoin    6.021918e+10  3631.72        1.658145e+07
# 1      2      Ethereum    2.506128e+10   264.44        9.477220e+07
# 2      3  Bitcoin Cash    6.815418e+09   410.47        1.660378e+07
# 3      4        Ripple    6.646330e+09     0.17        3.834384e+10
# 4      5          Dash    2.607961e+09   344.36        7.573378e+06
# ..   ...           ...             ...      ...                 ...
# 95    96         SaluS    1.227689e+07    12.23        1.004195e+06
# 96    97   Groestlcoin    1.221101e+07     0.18        6.843890e+07
# 97    98     BlackCoin    1.220832e+07     0.16        7.638651e+07
# 98    99         Golos    1.182068e+07     0.09        1.245189e+08
# 99   100      GridCoin    1.181625e+07     0.03        3.903128e+08
#
#      Volume(24h)  Change(24h)
# 0   1.226800e+09      -0.0084
# 1   4.625760e+08       0.0132
# 2   2.608570e+08      -0.0322
# ...

# %%
import seaborn as sns 
sns.barplot(x=df['Change(24h)'], y=df['Currency_Name'].sort_values().head(10))
# Out:
# <AxesSubplot:xlabel='Change(24h)', ylabel='Currency_Name'>

# %%
n = df.tail(10)
n
# Out:
#     Rank Currency_Name  Market_Capital  Price  Circulating_Supply  \
# 90    91      ATC Coin      12751674.0   1.21          10525960.0
# 91    92    Energycoin      12526103.0   0.10         121243039.0
# 92    93      Rubycoin      12519449.0   0.50          24792314.0
# 93    94        Gambit      12437419.0  10.42           1193530.0
# 94    95        E-coin      12348031.0   3.08           4008919.0
# 95    96         SaluS      12276886.0  12.23           1004195.0
# 96    97   Groestlcoin      12211006.0   0.18          68438903.0
# 97    98     BlackCoin      12208321.0   0.16          76386509.0
# 98    99         Golos      11820678.0   0.09         124518891.0
# 99   100      GridCoin      11816250.0   0.03         390312753.0
#
#     Volume(24h)  Change(24h)
# 90     498063.0      -0.0070
# 91      20940.0       0.0011
# 92      45798.0      -0.0788
# 93     114899.0       0.0029
# 94      69387.0      -0.0189
# 95      51408.0      -0.0408
# ...

# %%
n.sort_values(by=['Market_Capital','Currency_Name'], ascending=False)
# Out:
#     Rank Currency_Name  Market_Capital  Price  Circulating_Supply  \
# 90    91      ATC Coin      12751674.0   1.21          10525960.0
# 91    92    Energycoin      12526103.0   0.10         121243039.0
# 92    93      Rubycoin      12519449.0   0.50          24792314.0
# 93    94        Gambit      12437419.0  10.42           1193530.0
# 94    95        E-coin      12348031.0   3.08           4008919.0
# 95    96         SaluS      12276886.0  12.23           1004195.0
# 96    97   Groestlcoin      12211006.0   0.18          68438903.0
# 97    98     BlackCoin      12208321.0   0.16          76386509.0
# 98    99         Golos      11820678.0   0.09         124518891.0
# 99   100      GridCoin      11816250.0   0.03         390312753.0
#
#     Volume(24h)  Change(24h)
# 90     498063.0      -0.0070
# 91      20940.0       0.0011
# 92      45798.0      -0.0788
# 93     114899.0       0.0029
# 94      69387.0      -0.0189
# 95      51408.0      -0.0408
# ...

# %%
sns.barplot(x=df['Change(24h)'], y=df.sort_values(by=['Change(24h)','Currency_Name'], ascending=False).head(10)['Currency_Name'])
# Out:
# <AxesSubplot:xlabel='Change(24h)', ylabel='Currency_Name'>
